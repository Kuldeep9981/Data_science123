# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuldeep9981/Data_science123/blob/main/pandaspro_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/titanic2.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df.value_counts("Sex")
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.drop_duplicates(subset=["Sex"])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.drop_duplicates(subset=["Sex"],inplace=False)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df[["Name","Sex"]]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
# [891 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df.iloc[5,3]
# Out:
# 'Moran, Mr. James'

# %%
df.loc[[2,3],["Name","Sex"]]
# Out:
#                                            Name     Sex
# 2                        Heikkinen, Miss. Laina  female
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female

# %%
df.loc[[5],["Name","Sex"]]
# Out:
#                Name   Sex
# 5  Moran, Mr. James  male

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df.drop_duplicates(subset=["Pclass"])
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 9      0     237736  30.0708   NaN        C

# %%
df.value_counts("Pclass")
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.Cabin
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
x=df['Cabin'].isna().sum()
x
# Out:
# 687

# %%
df['Cabin'].isna()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df[df['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df['Cabin'].notna()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(how="any")
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna("Hard")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("mahadev")
# Out:
# mahadev

# %%
print("mahadev")
# Out:
# mahadev

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randn(10,5),index=["a","b","c","d","e","f","g","h","j","i"],columns=["first","second","third","fourth","fifth"])
df
# Out:
#       first    second     third    fourth     fifth
# a -1.134787 -1.467561 -0.911177 -1.018627 -0.187627
# b -0.022997  1.187819 -0.600168  0.133961 -1.429716
# c -0.492481  1.612012  0.815202  0.929938 -0.275083
# d -1.253981 -0.283953 -0.476845 -1.497384 -1.286762
# e -0.227803  0.433043 -0.781431 -1.634039  0.985044
# f -0.660663 -1.728166  0.903184  1.035619 -0.016612
# g  1.882117 -0.872981 -0.399262  0.338026 -1.308433
# h -2.137469 -0.997254 -0.634083  0.891858 -0.000197
# j -1.668546 -0.136839 -0.350710  0.406069 -0.789840
# i -0.538308 -0.011225  0.831867 -0.610167 -0.469291

# %%
s= pd.Series(np.random.randn(10))
s
# Out:
# 0    0.196740
# 1   -0.135592
# 2   -1.786971
# 3    0.830431
# 4   -0.847921
# 5   -0.514632
# 6   -0.592887
# 7    0.027631
# 8    0.095107
# 9   -0.418246
# dtype: float64

# %%
s= pd.Series(np.random.randn(20))
s
# Out:
# 0     0.116084
# 1     0.238717
# 2    -1.142942
# 3    -0.613426
# 4    -0.424753
# 5     1.400554
# 6     0.598807
# 7     1.486733
# 8     0.189016
# 9    -0.855376
# 10   -0.355604
# 11   -0.138869
# 12   -0.573162
# 13    2.463200
# 14    0.234238
# 15   -0.145877
# 16    0.081012
# 17    0.570834
# 18    0.970527
# 19    0.289831
# dtype: float64

# %%
df=pd.DataFrame(np.random.randint(low=0,high=10,size=(10,5)),columns=["a","b","c","d","e"])
df
# Out:
#    a  b  c  d  e
# 0  5  7  8  1  6
# 1  2  3  3  5  0
# 2  6  9  9  3  4
# 3  1  8  7  4  6
# 4  5  0  9  5  5
# 5  2  7  6  7  9
# 6  1  9  6  6  1
# 7  3  5  2  2  3
# 8  8  4  7  6  7
# 9  5  6  1  3  6

# %%
df[["a","b"]]
# Out:
#    a  b
# 0  5  7
# 1  2  3
# 2  6  9
# 3  1  8
# 4  5  0
# 5  2  7
# 6  1  9
# 7  3  5
# 8  8  4
# 9  5  6

# %%
df.loc[[1,3],["a"]]
# Out:
#    a
# 1  2
# 3  1

# %%
df.iloc[5,2]
# Out:
# 6

# %%
df.reset_index()
# Out:
#    index  a  b  c  d  e
# 0      0  5  7  8  1  6
# 1      1  2  3  3  5  0
# 2      2  6  9  9  3  4
# 3      3  1  8  7  4  6
# 4      4  5  0  9  5  5
# 5      5  2  7  6  7  9
# 6      6  1  9  6  6  1
# 7      7  3  5  2  2  3
# 8      8  8  4  7  6  7
# 9      9  5  6  1  3  6

# %%
df.set_index("a")
# Out:
#    b  c  d  e
# a
# 5  7  8  1  6
# 2  3  3  5  0
# 6  9  9  3  4
# 1  8  7  4  6
# 5  0  9  5  5
# 2  7  6  7  9
# 1  9  6  6  1
# 3  5  2  2  3
# 8  4  7  6  7
# 5  6  1  3  6

# %%
df.reindex(np.arange(5,15))
# Out:
#       a    b    c    d    e
# 5   2.0  7.0  6.0  7.0  9.0
# 6   1.0  9.0  6.0  6.0  1.0
# 7   3.0  5.0  2.0  2.0  3.0
# 8   8.0  4.0  7.0  6.0  7.0
# 9   5.0  6.0  1.0  3.0  6.0
# 10  NaN  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN  NaN

# %%
df
# Out:
#    a  b  c  d  e
# 0  5  7  8  1  6
# 1  2  3  3  5  0
# 2  6  9  9  3  4
# 3  1  8  7  4  6
# 4  5  0  9  5  5
# 5  2  7  6  7  9
# 6  1  9  6  6  1
# 7  3  5  2  2  3
# 8  8  4  7  6  7
# 9  5  6  1  3  6

# %%
new_index = [11,1,3,14,5,16,17,18,19,20]
x =df.reindex(new_index)
x
# Out:
#       a    b    c    d    e
# 11  NaN  NaN  NaN  NaN  NaN
# 1   2.0  3.0  3.0  5.0  0.0
# 3   1.0  8.0  7.0  4.0  6.0
# 14  NaN  NaN  NaN  NaN  NaN
# 5   2.0  7.0  6.0  7.0  9.0
# 16  NaN  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN  NaN

# %%
x.drop_duplicates(subset=["a"])
# Out:
#       a    b    c    d    e
# 11  NaN  NaN  NaN  NaN  NaN
# 1   2.0  3.0  3.0  5.0  0.0
# 3   1.0  8.0  7.0  4.0  6.0

# %%
x.value_counts("a")
# Out:
# a
# 2.0    2
# 1.0    1
# Name: count, dtype: int64

# %%
x["a"].isna().sum()
# Out:
# 7

# %%
df=pd.DataFrame({"name":['a','b','c'],"marks":np.array([3]*3,dtype = "int32")})
df
# Out:
#   name  marks
# 0    a      3
# 1    b      3
# 2    c      3

# %%
df["name"]= df["name"].str.replace("a","kuldeep")
df
# Out:
#       name  marks
# 0  kuldeep      3
# 1        b      3
# 2        c      3

# %%
missing_value = x[x['d'].isna()]
missing_value
# Out:
#      a   b   c   d   e
# 11 NaN NaN NaN NaN NaN
# 14 NaN NaN NaN NaN NaN
# 16 NaN NaN NaN NaN NaN
# 17 NaN NaN NaN NaN NaN
# 18 NaN NaN NaN NaN NaN
# 19 NaN NaN NaN NaN NaN
# 20 NaN NaN NaN NaN NaN
