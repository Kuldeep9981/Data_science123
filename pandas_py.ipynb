# %% [markdown]
# <a href="https://colab.research.google.com/github/Kuldeep9981/Data_science123/blob/main/pandas_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # p**andas library practice**

# %%
# question1.Write a Pandas program to create a dataframe from a dictionary and display
# it.
# Sample data: {&#39;X&#39;:[78,85,96,80,86], &#39;Y&#39;:[84,94,89,83,86],&#39;Z&#39;:[86,97,96,72,83]}

# %%
import pandas as pd
data = {"X":[78,85,96,80,86],"Y":[84,94,89,83,86],"Z":[86,97,96,72,83]}
pd.DataFrame(data)
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %%
# question2. Write a Pandas program to create and display a DataFrame from a specified
# dictionary data which has the index labels.
# Sample Python dictionary data and list labels:

# %%
import numpy as np
import pandas as pd

# %%
data = {"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']
df= pd.DataFrame(data,index=label)
df
# Out:
#        names  score  attempts qalify
# a  Anastasia   12.5         1    yes
# b       dima    9.0         3     no
# c  katherine   16.5         2    yes
# d      james    NaN         3     no
# e      emily    9.0         2     no
# f    michael   20.0         3    yes
# g    Matthew   14.5         1    yes
# h      Laura    NaN         1     no
# i      Kevin    8.0         2     no
# j      Jonas   19.0         1    yes

# %%
#question3 Write a Pandas program to get the first 3 rows of a given DataFrame.
# Sample Python dictionary data and list labels:

# %%
exam_data ={"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']

# %%
df = pd.DataFrame(exam_data,index = label)
df.head(3)
# Out:
#        names  score  attempts qalify
# a  Anastasia   12.5         1    yes
# b       dima    9.0         3     no
# c  katherine   16.5         2    yes

# %%
#Write a Pandas program to select the &#39;name&#39; and &#39;score&#39; columns from the
# following DataFrame.
exam_data ={"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']
df[['names','score']]
# Out:
#        names  score
# a  Anastasia   12.5
# b       dima    9.0
# c  katherine   16.5
# d      james    NaN
# e      emily    9.0
# f    michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %%
# Write a Pandas program to select the rows where the number of attempts in
# the examination is greater than 2.
exam_data ={"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data,index = label)
df.loc[(df['attempts']>2)]
# Out:
#      names  score  attempts qalify
# b     dima    9.0         3     no
# d    james    NaN         3     no
# f  michael   20.0         3    yes

# %%
# Write a Pandas program to select the rows where the score is missing, i.e.
# is NaN.
exam_data ={"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']
df  = pd.DataFrame(data,index=label)
df[df['score'].isna()]
# Out:
#    names  score  attempts qalify
# d  james    NaN         3     no
# h  Laura    NaN         1     no

# %%
# Write a Pandas program to calculate the mean of all students&#39; scores. Data
# is stored in a dataframe.
exam_data ={"names":['Anastasia','dima','katherine','james','emily','michael','Matthew','Laura','Kevin','Jonas'],"score":[12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],"attempts":[1, 3, 2, 3, 2, 3, 1, 1, 2, 1],"qalify":['yes','no','yes','no','no','yes','yes','no','no','yes']}
label = ['a','b','c','d','e','f','g','h','i','j']
df = pd.DataFrame(exam_data,index=label)
df['score'].mean()
# Out:
# 13.5625

# %%
# Write a Pandas program to join the two given dataframes along rows and
# assign all data.
# Test Data:
# student_data1:
# student_id name marks
# 0 S1 Danniella Fenton 200
# 1 S2 Ryder Storey 210
# 2 S3 Bryce Jensen 190
# 3 S4 Ed Bernal 222
# 4 S5 Kwame Morin 199
# student_data2:
# student_id name marks
# 0 S4 Scarlette Fisher 201
# 1 S5 Carla Williamson 200
# 2 S6 Dante Morse 198
# 3 S7 Kaiser William 219
# 4 S8 Madeeha Preston 201

# %%
import pandas as pd
import numpy as np
student_data1={"student_id":['S1','S2','S3','S4','S5'],"name":['danniella ferton','ryder storey','bryce lensen','ed bernal','kwame morni'],"marks":[200,210,190,222,199]}
df1 = pd.DataFrame(student_data1)
df1
# Out:
#   student_id              name  marks
# 0         S1  danniella ferton    200
# 1         S2      ryder storey    210
# 2         S3      bryce lensen    190
# 3         S4         ed bernal    222
# 4         S5       kwame morni    199

# %%
student_data2 = {"student_id":['S1','S2','S3','S4','S5'],"name":['Scarlette Fisher','Carla Williamson','Dante Morse','Kaiser William','Madeeha Preston'],"marks":[210,200,198,219,201]}
df2 = pd.DataFrame(student_data2)
df2
# Out:
#   student_id              name  marks
# 0         S1  Scarlette Fisher    210
# 1         S2  Carla Williamson    200
# 2         S3       Dante Morse    198
# 3         S4    Kaiser William    219
# 4         S5   Madeeha Preston    201

# %%
df3 =pd.concat([df1,df2])
df3
# Out:
#   student_id              name  marks
# 0         S1  danniella ferton    200
# 1         S2      ryder storey    210
# 2         S3      bryce lensen    190
# 3         S4         ed bernal    222
# 4         S5       kwame morni    199
# 0         S1  Scarlette Fisher    210
# 1         S2  Carla Williamson    200
# 2         S3       Dante Morse    198
# 3         S4    Kaiser William    219
# 4         S5   Madeeha Preston    201

# %%
#joining two data frame along to column
df4 = pd.concat([df1,df2],axis=1)
df4
# Out:
#   student_id              name  marks student_id              name  marks
# 0         S1  danniella ferton    200         S1  Scarlette Fisher    210
# 1         S2      ryder storey    210         S2  Carla Williamson    200
# 2         S3      bryce lensen    190         S3       Dante Morse    198
# 3         S4         ed bernal    222         S4    Kaiser William    219
# 4         S5       kwame morni    199         S5   Madeeha Preston    201
